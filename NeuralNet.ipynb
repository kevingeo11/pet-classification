# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore')

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.initializers import glorot_uniform
from tensorflow.keras import regularizers

import keras.backend as K
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.externals.joblib import load
from keras.models import load_model
import seaborn as sb
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio

# comment the below line if you not using jupyter notebook
# %matplotlib inline

# %%
print("Started reading the data for training...")
df_ = pd.read_csv('train.csv')
df = df_.copy()
# df_training = df.iloc[:,:].copy()
print("Finished reading the data")
# Out:
# Started reading the data for training...
# Finished reading the data

# %%
df.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#     color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0  Brown Tabby       0.80        7.78  13   9             0.0             1
# 1        White       0.72       14.19  13   9             0.0             2
# 2        Brown       0.15       40.90  15   4             2.0             4
# 3        White       0.62       17.82   0   1             0.0             2
# 4        Black       0.50       11.06  18   4             0.0             1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['color_type'])
df['color_type'] = le.transform(df['color_type'])

# %%
df.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#    color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0          18       0.80        7.78  13   9             0.0             1
# 1          53       0.72       14.19  13   9             0.0             2
# 2          15       0.15       40.90  15   4             2.0             4
# 3          53       0.62       17.82   0   1             0.0             2
# 4           2       0.50       11.06  18   4             0.0             1

# %%
from sklearn.preprocessing import OneHotEncoder
enc_y1 = OneHotEncoder(handle_unknown='ignore')
enc_y1.fit(df[['breed_category']])
y1 = enc_y1.transform(df[['breed_category']]).toarray()
enc_y2 = OneHotEncoder(handle_unknown='ignore')
enc_y2.fit(df[['pet_category']])
y2 = enc_y2.transform(df[['pet_category']]).toarray()

# %%
y = np.append(y1,y2,axis=1)

# %%
df[['condition']] = df[['condition']].fillna(3.0)

# %%
df.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        3.0
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#    color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0          18       0.80        7.78  13   9             0.0             1
# 1          53       0.72       14.19  13   9             0.0             2
# 2          15       0.15       40.90  15   4             2.0             4
# 3          53       0.62       17.82   0   1             0.0             2
# 4           2       0.50       11.06  18   4             0.0             1

# %%
x = df[['condition', 'color_type', 'length(m)', 'height(cm)', 'X1', 'X2']].values

# %%
def scaleData(x, y):
    sc_x = StandardScaler()
    sc_y = StandardScaler()

    sc_x.fit(x)
    sc_y.fit(y)
    
    return sc_x, sc_y

# %%
sc_x, sc_y = scaleData(x,y)

# %%
x_scaled = sc_x.transform(x)

# %%
x_train = x_scaled[:15000,:]
y_train = y[:15000,:]
x_val = x_scaled[15000:,:]
y_val = y[15000:,:]

# %%
model = Sequential()
Kreg = regularizers.l2(1e-4)

model.add(Dense(64, activation = 'relu', input_shape = (x_train.shape[1],),
                kernel_initializer = glorot_uniform(seed = 1), kernel_regularizer = Kreg))

model.add(Dense(64, activation = 'relu',
                kernel_initializer = glorot_uniform(seed = 2), kernel_regularizer = Kreg))

model.add(Dense(64, activation = 'relu',
                kernel_initializer = glorot_uniform(seed = 3), kernel_regularizer = Kreg))

model.add(Dense(7, activation = 'sigmoid',
                kernel_initializer = glorot_uniform(seed = 4), kernel_regularizer = Kreg))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 64)                448
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 455
# =================================================================
# Total params: 9,223
# Trainable params: 9,223
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(learning_rate = 0.001)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics = ['categorical_accuracy'])

es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=10)
mc = ModelCheckpoint('model_cond-4-64.h5', monitor='loss', mode='min', save_best_only=True, verbose=1)
callbacks = [es, mc]

history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data = (x_val,y_val),
                    verbose = 1, callbacks = callbacks)
# Out:
# Epoch 1/100
# 454/469 [============================>.] - ETA: 0s - loss: 2.4949 - categorical_accuracy: 0.5432
# Epoch 00001: loss improved from inf to 2.48574, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.4857 - categorical_accuracy: 0.5503 - val_loss: 2.2248 - val_categorical_accuracy: 0.7100
# Epoch 2/100
# 457/469 [============================>.] - ETA: 0s - loss: 2.1821 - categorical_accuracy: 0.7463
# Epoch 00002: loss improved from 2.48574 to 2.18161, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1816 - categorical_accuracy: 0.7473 - val_loss: 2.1902 - val_categorical_accuracy: 0.7728
# Epoch 3/100
# 449/469 [===========================>..] - ETA: 0s - loss: 2.1640 - categorical_accuracy: 0.7706
# Epoch 00003: loss improved from 2.18161 to 2.16160, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1616 - categorical_accuracy: 0.7691 - val_loss: 2.1835 - val_categorical_accuracy: 0.7201
# Epoch 4/100
# 458/469 [============================>.] - ETA: 0s - loss: 2.1535 - categorical_accuracy: 0.7691
# Epoch 00004: loss improved from 2.16160 to 2.15287, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1529 - categorical_accuracy: 0.7693 - val_loss: 2.1779 - val_categorical_accuracy: 0.7608
# Epoch 5/100
# 456/469 [============================>.] - ETA: 0s - loss: 2.1488 - categorical_accuracy: 0.7729
# Epoch 00005: loss improved from 2.15287 to 2.14844, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1484 - categorical_accuracy: 0.7720 - val_loss: 2.1790 - val_categorical_accuracy: 0.7577
# Epoch 6/100
# 453/469 [===========================>..] - ETA: 0s - loss: 2.1421 - categorical_accuracy: 0.7679
# Epoch 00006: loss improved from 2.14844 to 2.14283, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1428 - categorical_accuracy: 0.7661 - val_loss: 2.1756 - val_categorical_accuracy: 0.7332
# Epoch 7/100
# 454/469 [============================>.] - ETA: 0s - loss: 2.1415 - categorical_accuracy: 0.7623
# Epoch 00007: loss improved from 2.14283 to 2.14055, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1405 - categorical_accuracy: 0.7619 - val_loss: 2.1819 - val_categorical_accuracy: 0.7512
# Epoch 8/100
# 435/469 [==========================>...] - ETA: 0s - loss: 2.1362 - categorical_accuracy: 0.7532
# Epoch 00008: loss improved from 2.14055 to 2.13467, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1347 - categorical_accuracy: 0.7543 - val_loss: 2.1691 - val_categorical_accuracy: 0.7509
# Epoch 9/100
# 446/469 [===========================>..] - ETA: 0s - loss: 2.1308 - categorical_accuracy: 0.7570
# Epoch 00009: loss improved from 2.13467 to 2.13210, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 5ms/step - loss: 2.1321 - categorical_accuracy: 0.7569 - val_loss: 2.1710 - val_categorical_accuracy: 0.7809
# Epoch 10/100
# 449/469 [===========================>..] - ETA: 0s - loss: 2.1265 - categorical_accuracy: 0.7538
# Epoch 00010: loss improved from 2.13210 to 2.12880, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1288 - categorical_accuracy: 0.7545 - val_loss: 2.1711 - val_categorical_accuracy: 0.7517
# Epoch 11/100
# 449/469 [===========================>..] - ETA: 0s - loss: 2.1280 - categorical_accuracy: 0.7609
# Epoch 00011: loss improved from 2.12880 to 2.12661, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1266 - categorical_accuracy: 0.7611 - val_loss: 2.1614 - val_categorical_accuracy: 0.7486
# Epoch 12/100
# 438/469 [===========================>..] - ETA: 0s - loss: 2.1280 - categorical_accuracy: 0.7572
# Epoch 00012: loss improved from 2.12661 to 2.12469, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1247 - categorical_accuracy: 0.7569 - val_loss: 2.1642 - val_categorical_accuracy: 0.7431
# Epoch 13/100
# 468/469 [============================>.] - ETA: 0s - loss: 2.1214 - categorical_accuracy: 0.7555
# Epoch 00013: loss improved from 2.12469 to 2.12104, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1210 - categorical_accuracy: 0.7556 - val_loss: 2.1626 - val_categorical_accuracy: 0.7486
# Epoch 14/100
# 465/469 [============================>.] - ETA: 0s - loss: 2.1193 - categorical_accuracy: 0.7557
# Epoch 00014: loss improved from 2.12104 to 2.11974, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1197 - categorical_accuracy: 0.7562 - val_loss: 2.1611 - val_categorical_accuracy: 0.7259
# Epoch 15/100
# 468/469 [============================>.] - ETA: 0s - loss: 2.1177 - categorical_accuracy: 0.7546
# Epoch 00015: loss improved from 2.11974 to 2.11748, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1175 - categorical_accuracy: 0.7549 - val_loss: 2.1605 - val_categorical_accuracy: 0.7692
# Epoch 16/100
# 438/469 [===========================>..] - ETA: 0s - loss: 2.1130 - categorical_accuracy: 0.7571
# Epoch 00016: loss improved from 2.11748 to 2.11450, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1145 - categorical_accuracy: 0.7552 - val_loss: 2.1608 - val_categorical_accuracy: 0.7371
# Epoch 17/100
# 461/469 [============================>.] - ETA: 0s - loss: 2.1131 - categorical_accuracy: 0.7486
# Epoch 00017: loss improved from 2.11450 to 2.11335, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 5ms/step - loss: 2.1134 - categorical_accuracy: 0.7479 - val_loss: 2.1521 - val_categorical_accuracy: 0.7178
# Epoch 18/100
# 455/469 [============================>.] - ETA: 0s - loss: 2.1091 - categorical_accuracy: 0.7466
# Epoch 00018: loss improved from 2.11335 to 2.11022, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1102 - categorical_accuracy: 0.7467 - val_loss: 2.1520 - val_categorical_accuracy: 0.7632
# Epoch 19/100
# 447/469 [===========================>..] - ETA: 0s - loss: 2.1096 - categorical_accuracy: 0.7627
# Epoch 00019: loss improved from 2.11022 to 2.10937, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1094 - categorical_accuracy: 0.7614 - val_loss: 2.1573 - val_categorical_accuracy: 0.7230
# Epoch 20/100
# 467/469 [============================>.] - ETA: 0s - loss: 2.1067 - categorical_accuracy: 0.7421
# Epoch 00020: loss improved from 2.10937 to 2.10670, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 3ms/step - loss: 2.1067 - categorical_accuracy: 0.7419 - val_loss: 2.1593 - val_categorical_accuracy: 0.7543
# Epoch 21/100
# 466/469 [============================>.] - ETA: 0s - loss: 2.1058 - categorical_accuracy: 0.7458
# Epoch 00021: loss improved from 2.10670 to 2.10638, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1064 - categorical_accuracy: 0.7457 - val_loss: 2.1542 - val_categorical_accuracy: 0.7392
# Epoch 22/100
# 461/469 [============================>.] - ETA: 0s - loss: 2.1059 - categorical_accuracy: 0.7511
# Epoch 00022: loss improved from 2.10638 to 2.10448, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1045 - categorical_accuracy: 0.7513 - val_loss: 2.1550 - val_categorical_accuracy: 0.7668
# Epoch 23/100
# 464/469 [============================>.] - ETA: 0s - loss: 2.1037 - categorical_accuracy: 0.7459
# Epoch 00023: loss improved from 2.10448 to 2.10287, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 5ms/step - loss: 2.1029 - categorical_accuracy: 0.7457 - val_loss: 2.1454 - val_categorical_accuracy: 0.7405
# Epoch 24/100
# 464/469 [============================>.] - ETA: 0s - loss: 2.1011 - categorical_accuracy: 0.7403
# Epoch 00024: loss improved from 2.10287 to 2.10009, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.1001 - categorical_accuracy: 0.7407 - val_loss: 2.1547 - val_categorical_accuracy: 0.7413
# Epoch 25/100
# 453/469 [===========================>..] - ETA: 0s - loss: 2.0980 - categorical_accuracy: 0.7329
# Epoch 00025: loss improved from 2.10009 to 2.09563, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0956 - categorical_accuracy: 0.7342 - val_loss: 2.1423 - val_categorical_accuracy: 0.7306
# Epoch 26/100
# 443/469 [===========================>..] - ETA: 0s - loss: 2.0934 - categorical_accuracy: 0.7384
# Epoch 00026: loss improved from 2.09563 to 2.09358, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0936 - categorical_accuracy: 0.7376 - val_loss: 2.1415 - val_categorical_accuracy: 0.7217
# Epoch 27/100
# 447/469 [===========================>..] - ETA: 0s - loss: 2.0938 - categorical_accuracy: 0.7397
# Epoch 00027: loss improved from 2.09358 to 2.09216, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0922 - categorical_accuracy: 0.7401 - val_loss: 2.1390 - val_categorical_accuracy: 0.7366
# Epoch 28/100
# 458/469 [============================>.] - ETA: 0s - loss: 2.0902 - categorical_accuracy: 0.7314
# Epoch 00028: loss improved from 2.09216 to 2.08994, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0899 - categorical_accuracy: 0.7311 - val_loss: 2.1409 - val_categorical_accuracy: 0.7449
# Epoch 29/100
# 455/469 [============================>.] - ETA: 0s - loss: 2.0874 - categorical_accuracy: 0.7341
# Epoch 00029: loss improved from 2.08994 to 2.08684, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 3ms/step - loss: 2.0868 - categorical_accuracy: 0.7349 - val_loss: 2.1344 - val_categorical_accuracy: 0.7300
# Epoch 30/100
# 445/469 [===========================>..] - ETA: 0s - loss: 2.0861 - categorical_accuracy: 0.7288
# Epoch 00030: loss improved from 2.08684 to 2.08500, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0850 - categorical_accuracy: 0.7291 - val_loss: 2.1386 - val_categorical_accuracy: 0.7207
# Epoch 31/100
# 453/469 [===========================>..] - ETA: 0s - loss: 2.0831 - categorical_accuracy: 0.7276
# Epoch 00031: loss improved from 2.08500 to 2.08293, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0829 - categorical_accuracy: 0.7261 - val_loss: 2.1369 - val_categorical_accuracy: 0.7063
# Epoch 32/100
# 467/469 [============================>.] - ETA: 0s - loss: 2.0819 - categorical_accuracy: 0.7252
# Epoch 00032: loss improved from 2.08293 to 2.08212, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0821 - categorical_accuracy: 0.7250 - val_loss: 2.1247 - val_categorical_accuracy: 0.7374
# Epoch 33/100
# 468/469 [============================>.] - ETA: 0s - loss: 2.0810 - categorical_accuracy: 0.7300
# Epoch 00033: loss improved from 2.08212 to 2.08094, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0809 - categorical_accuracy: 0.7301 - val_loss: 2.1310 - val_categorical_accuracy: 0.7300
# Epoch 34/100
# 469/469 [==============================] - ETA: 0s - loss: 2.0798 - categorical_accuracy: 0.7280
# Epoch 00034: loss improved from 2.08094 to 2.07975, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0798 - categorical_accuracy: 0.7280 - val_loss: 2.1277 - val_categorical_accuracy: 0.7045
# Epoch 35/100
# 468/469 [============================>.] - ETA: 0s - loss: 2.0775 - categorical_accuracy: 0.7304
# Epoch 00035: loss improved from 2.07975 to 2.07746, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 4ms/step - loss: 2.0775 - categorical_accuracy: 0.7308 - val_loss: 2.1277 - val_categorical_accuracy: 0.7199
# Epoch 36/100
# 445/469 [===========================>..] - ETA: 0s - loss: 2.0773 - categorical_accuracy: 0.7264
# Epoch 00036: loss improved from 2.07746 to 2.07637, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0764 - categorical_accuracy: 0.7247 - val_loss: 2.1281 - val_categorical_accuracy: 0.6946
# Epoch 37/100
# 456/469 [============================>.] - ETA: 0s - loss: 2.0778 - categorical_accuracy: 0.7331
# Epoch 00037: loss improved from 2.07637 to 2.07511, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0751 - categorical_accuracy: 0.7315 - val_loss: 2.1322 - val_categorical_accuracy: 0.6808
# Epoch 38/100
# 451/469 [===========================>..] - ETA: 0s - loss: 2.0737 - categorical_accuracy: 0.7167
# Epoch 00038: loss improved from 2.07511 to 2.07281, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0728 - categorical_accuracy: 0.7170 - val_loss: 2.1262 - val_categorical_accuracy: 0.7173
# Epoch 39/100
# 449/469 [===========================>..] - ETA: 0s - loss: 2.0740 - categorical_accuracy: 0.7281
# Epoch 00039: loss did not improve from 2.07281
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0734 - categorical_accuracy: 0.7284 - val_loss: 2.1220 - val_categorical_accuracy: 0.6912
# Epoch 40/100
# 451/469 [===========================>..] - ETA: 0s - loss: 2.0739 - categorical_accuracy: 0.7269
# Epoch 00040: loss improved from 2.07281 to 2.07254, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0725 - categorical_accuracy: 0.7277 - val_loss: 2.1314 - val_categorical_accuracy: 0.7034
# Epoch 41/100
# 453/469 [===========================>..] - ETA: 0s - loss: 2.0706 - categorical_accuracy: 0.7199
# Epoch 00041: loss improved from 2.07254 to 2.07218, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0722 - categorical_accuracy: 0.7190 - val_loss: 2.1165 - val_categorical_accuracy: 0.7329
# Epoch 42/100
# 452/469 [===========================>..] - ETA: 0s - loss: 2.0698 - categorical_accuracy: 0.7193
# Epoch 00042: loss improved from 2.07218 to 2.06844, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0684 - categorical_accuracy: 0.7189 - val_loss: 2.1277 - val_categorical_accuracy: 0.6985
# Epoch 43/100
# 444/469 [===========================>..] - ETA: 0s - loss: 2.0695 - categorical_accuracy: 0.7223
# Epoch 00043: loss improved from 2.06844 to 2.06715, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0671 - categorical_accuracy: 0.7227 - val_loss: 2.1218 - val_categorical_accuracy: 0.7131
# Epoch 44/100
# 456/469 [============================>.] - ETA: 0s - loss: 2.0683 - categorical_accuracy: 0.7137
# Epoch 00044: loss did not improve from 2.06715
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0682 - categorical_accuracy: 0.7147 - val_loss: 2.1193 - val_categorical_accuracy: 0.7397
# Epoch 45/100
# 450/469 [===========================>..] - ETA: 0s - loss: 2.0657 - categorical_accuracy: 0.7098
# Epoch 00045: loss improved from 2.06715 to 2.06651, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0665 - categorical_accuracy: 0.7095 - val_loss: 2.1164 - val_categorical_accuracy: 0.7332
# Epoch 46/100
# 450/469 [===========================>..] - ETA: 0s - loss: 2.0661 - categorical_accuracy: 0.7085
# Epoch 00046: loss improved from 2.06651 to 2.06553, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0655 - categorical_accuracy: 0.7079 - val_loss: 2.1108 - val_categorical_accuracy: 0.7087
# Epoch 47/100
# 446/469 [===========================>..] - ETA: 0s - loss: 2.0634 - categorical_accuracy: 0.7061
# Epoch 00047: loss improved from 2.06553 to 2.06394, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0639 - categorical_accuracy: 0.7057 - val_loss: 2.1180 - val_categorical_accuracy: 0.7183
# Epoch 48/100
# 467/469 [============================>.] - ETA: 0s - loss: 2.0641 - categorical_accuracy: 0.7117
# Epoch 00048: loss improved from 2.06394 to 2.06330, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0633 - categorical_accuracy: 0.7118 - val_loss: 2.1251 - val_categorical_accuracy: 0.6818
# Epoch 49/100
# 453/469 [===========================>..] - ETA: 0s - loss: 2.0637 - categorical_accuracy: 0.7052
# Epoch 00049: loss improved from 2.06330 to 2.06272, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0627 - categorical_accuracy: 0.7048 - val_loss: 2.1217 - val_categorical_accuracy: 0.6588
# Epoch 50/100
# 441/469 [===========================>..] - ETA: 0s - loss: 2.0602 - categorical_accuracy: 0.7025
# Epoch 00050: loss improved from 2.06272 to 2.06035, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0604 - categorical_accuracy: 0.7037 - val_loss: 2.1114 - val_categorical_accuracy: 0.7063
# Epoch 51/100
# 469/469 [==============================] - ETA: 0s - loss: 2.0588 - categorical_accuracy: 0.6975
# Epoch 00051: loss improved from 2.06035 to 2.05883, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0588 - categorical_accuracy: 0.6975 - val_loss: 2.1119 - val_categorical_accuracy: 0.6695
# Epoch 52/100
# 457/469 [============================>.] - ETA: 0s - loss: 2.0570 - categorical_accuracy: 0.6933
# Epoch 00052: loss improved from 2.05883 to 2.05772, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0577 - categorical_accuracy: 0.6952 - val_loss: 2.1185 - val_categorical_accuracy: 0.7027
# Epoch 53/100
# 436/469 [==========================>...] - ETA: 0s - loss: 2.0572 - categorical_accuracy: 0.6933
# Epoch 00053: loss improved from 2.05772 to 2.05701, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0570 - categorical_accuracy: 0.6923 - val_loss: 2.1151 - val_categorical_accuracy: 0.6492
# Epoch 54/100
# 464/469 [============================>.] - ETA: 0s - loss: 2.0538 - categorical_accuracy: 0.6877
# Epoch 00054: loss improved from 2.05701 to 2.05410, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0541 - categorical_accuracy: 0.6876 - val_loss: 2.1028 - val_categorical_accuracy: 0.7376
# Epoch 55/100
# 457/469 [============================>.] - ETA: 0s - loss: 2.0545 - categorical_accuracy: 0.6879
# Epoch 00055: loss improved from 2.05410 to 2.05251, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0525 - categorical_accuracy: 0.6893 - val_loss: 2.1136 - val_categorical_accuracy: 0.6901
# Epoch 56/100
# 454/469 [============================>.] - ETA: 0s - loss: 2.0521 - categorical_accuracy: 0.6925
# Epoch 00056: loss improved from 2.05251 to 2.05208, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0521 - categorical_accuracy: 0.6920 - val_loss: 2.1044 - val_categorical_accuracy: 0.6917
# Epoch 57/100
# 443/469 [===========================>..] - ETA: 0s - loss: 2.0485 - categorical_accuracy: 0.6845
# Epoch 00057: loss improved from 2.05208 to 2.04938, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0494 - categorical_accuracy: 0.6851 - val_loss: 2.0988 - val_categorical_accuracy: 0.7175
# Epoch 58/100
# 463/469 [============================>.] - ETA: 0s - loss: 2.0468 - categorical_accuracy: 0.6834
# Epoch 00058: loss improved from 2.04938 to 2.04776, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0478 - categorical_accuracy: 0.6831 - val_loss: 2.1067 - val_categorical_accuracy: 0.6794
# Epoch 59/100
# 460/469 [============================>.] - ETA: 0s - loss: 2.0450 - categorical_accuracy: 0.6772
# Epoch 00059: loss improved from 2.04776 to 2.04516, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0452 - categorical_accuracy: 0.6783 - val_loss: 2.1066 - val_categorical_accuracy: 0.7019
# Epoch 60/100
# 451/469 [===========================>..] - ETA: 0s - loss: 2.0432 - categorical_accuracy: 0.6873
# Epoch 00060: loss improved from 2.04516 to 2.04229, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0423 - categorical_accuracy: 0.6872 - val_loss: 2.0942 - val_categorical_accuracy: 0.6479
# Epoch 61/100
# 467/469 [============================>.] - ETA: 0s - loss: 2.0424 - categorical_accuracy: 0.6720
# Epoch 00061: loss did not improve from 2.04229
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0423 - categorical_accuracy: 0.6721 - val_loss: 2.0919 - val_categorical_accuracy: 0.6941
# Epoch 62/100
# 466/469 [============================>.] - ETA: 0s - loss: 2.0411 - categorical_accuracy: 0.6719
# Epoch 00062: loss improved from 2.04229 to 2.04072, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0407 - categorical_accuracy: 0.6722 - val_loss: 2.0885 - val_categorical_accuracy: 0.6834
# Epoch 63/100
# 468/469 [============================>.] - ETA: 0s - loss: 2.0388 - categorical_accuracy: 0.6792
# Epoch 00063: loss improved from 2.04072 to 2.03863, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 3ms/step - loss: 2.0386 - categorical_accuracy: 0.6791 - val_loss: 2.0984 - val_categorical_accuracy: 0.6416
# Epoch 64/100
# 464/469 [============================>.] - ETA: 0s - loss: 2.0363 - categorical_accuracy: 0.6697
# Epoch 00064: loss improved from 2.03863 to 2.03592, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0359 - categorical_accuracy: 0.6696 - val_loss: 2.0878 - val_categorical_accuracy: 0.6753
# Epoch 65/100
# 441/469 [===========================>..] - ETA: 0s - loss: 2.0355 - categorical_accuracy: 0.6643
# Epoch 00065: loss did not improve from 2.03592
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0363 - categorical_accuracy: 0.6645 - val_loss: 2.0855 - val_categorical_accuracy: 0.6667
# Epoch 66/100
# 439/469 [===========================>..] - ETA: 0s - loss: 2.0321 - categorical_accuracy: 0.6639
# Epoch 00066: loss improved from 2.03592 to 2.03221, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0322 - categorical_accuracy: 0.6627 - val_loss: 2.0888 - val_categorical_accuracy: 0.6255
# Epoch 67/100
# 446/469 [===========================>..] - ETA: 0s - loss: 2.0322 - categorical_accuracy: 0.6633
# Epoch 00067: loss did not improve from 2.03221
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0325 - categorical_accuracy: 0.6655 - val_loss: 2.0982 - val_categorical_accuracy: 0.6432
# Epoch 68/100
# 444/469 [===========================>..] - ETA: 0s - loss: 2.0298 - categorical_accuracy: 0.6647
# Epoch 00068: loss improved from 2.03221 to 2.02935, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0293 - categorical_accuracy: 0.6651 - val_loss: 2.0825 - val_categorical_accuracy: 0.6406
# Epoch 69/100
# 458/469 [============================>.] - ETA: 0s - loss: 2.0282 - categorical_accuracy: 0.6588
# Epoch 00069: loss improved from 2.02935 to 2.02768, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0277 - categorical_accuracy: 0.6579 - val_loss: 2.0955 - val_categorical_accuracy: 0.6468
# Epoch 70/100
# 457/469 [============================>.] - ETA: 0s - loss: 2.0240 - categorical_accuracy: 0.6546
# Epoch 00070: loss improved from 2.02768 to 2.02475, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0248 - categorical_accuracy: 0.6562 - val_loss: 2.0791 - val_categorical_accuracy: 0.6734
# Epoch 71/100
# 451/469 [===========================>..] - ETA: 0s - loss: 2.0239 - categorical_accuracy: 0.6511
# Epoch 00071: loss improved from 2.02475 to 2.02413, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0241 - categorical_accuracy: 0.6515 - val_loss: 2.0861 - val_categorical_accuracy: 0.6528
# Epoch 72/100
# 465/469 [============================>.] - ETA: 0s - loss: 2.0234 - categorical_accuracy: 0.6576
# Epoch 00072: loss improved from 2.02413 to 2.02332, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0233 - categorical_accuracy: 0.6575 - val_loss: 2.0753 - val_categorical_accuracy: 0.6654
# Epoch 73/100
# 460/469 [============================>.] - ETA: 0s - loss: 2.0210 - categorical_accuracy: 0.6537
# Epoch 00073: loss improved from 2.02332 to 2.01993, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0199 - categorical_accuracy: 0.6530 - val_loss: 2.0733 - val_categorical_accuracy: 0.6526
# Epoch 74/100
# 454/469 [============================>.] - ETA: 0s - loss: 2.0181 - categorical_accuracy: 0.6487
# Epoch 00074: loss improved from 2.01993 to 2.01827, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0183 - categorical_accuracy: 0.6497 - val_loss: 2.0825 - val_categorical_accuracy: 0.6171
# Epoch 75/100
# 461/469 [============================>.] - ETA: 0s - loss: 2.0166 - categorical_accuracy: 0.6408
# Epoch 00075: loss improved from 2.01827 to 2.01589, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0159 - categorical_accuracy: 0.6423 - val_loss: 2.0727 - val_categorical_accuracy: 0.6776
# Epoch 76/100
# 447/469 [===========================>..] - ETA: 0s - loss: 2.0134 - categorical_accuracy: 0.6438
# Epoch 00076: loss improved from 2.01589 to 2.01279, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0128 - categorical_accuracy: 0.6445 - val_loss: 2.0771 - val_categorical_accuracy: 0.5889
# Epoch 77/100
# 469/469 [==============================] - ETA: 0s - loss: 2.0112 - categorical_accuracy: 0.6372
# Epoch 00077: loss improved from 2.01279 to 2.01124, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0112 - categorical_accuracy: 0.6372 - val_loss: 2.0684 - val_categorical_accuracy: 0.6135
# Epoch 78/100
# 462/469 [============================>.] - ETA: 0s - loss: 2.0089 - categorical_accuracy: 0.6315
# Epoch 00078: loss improved from 2.01124 to 2.00923, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0092 - categorical_accuracy: 0.6313 - val_loss: 2.0784 - val_categorical_accuracy: 0.6406
# Epoch 79/100
# 456/469 [============================>.] - ETA: 0s - loss: 2.0075 - categorical_accuracy: 0.6312
# Epoch 00079: loss improved from 2.00923 to 2.00797, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0080 - categorical_accuracy: 0.6310 - val_loss: 2.0647 - val_categorical_accuracy: 0.6288
# Epoch 80/100
# 447/469 [===========================>..] - ETA: 0s - loss: 2.0111 - categorical_accuracy: 0.6291
# Epoch 00080: loss did not improve from 2.00797
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0093 - categorical_accuracy: 0.6283 - val_loss: 2.0732 - val_categorical_accuracy: 0.6343
# Epoch 81/100
# 451/469 [===========================>..] - ETA: 0s - loss: 2.0090 - categorical_accuracy: 0.6310
# Epoch 00081: loss improved from 2.00797 to 2.00776, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0078 - categorical_accuracy: 0.6300 - val_loss: 2.0733 - val_categorical_accuracy: 0.6049
# Epoch 82/100
# 464/469 [============================>.] - ETA: 0s - loss: 2.0033 - categorical_accuracy: 0.6290
# Epoch 00082: loss improved from 2.00776 to 2.00334, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0033 - categorical_accuracy: 0.6287 - val_loss: 2.0641 - val_categorical_accuracy: 0.6103
# Epoch 83/100
# 467/469 [============================>.] - ETA: 0s - loss: 2.0028 - categorical_accuracy: 0.6213
# Epoch 00083: loss did not improve from 2.00334
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0035 - categorical_accuracy: 0.6210 - val_loss: 2.0650 - val_categorical_accuracy: 0.5819
# Epoch 84/100
# 462/469 [============================>.] - ETA: 0s - loss: 2.0009 - categorical_accuracy: 0.6248
# Epoch 00084: loss improved from 2.00334 to 2.00067, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 5ms/step - loss: 2.0007 - categorical_accuracy: 0.6251 - val_loss: 2.0511 - val_categorical_accuracy: 0.6161
# Epoch 85/100
# 460/469 [============================>.] - ETA: 0s - loss: 1.9989 - categorical_accuracy: 0.6204
# Epoch 00085: loss improved from 2.00067 to 1.99933, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 5ms/step - loss: 1.9993 - categorical_accuracy: 0.6193 - val_loss: 2.0617 - val_categorical_accuracy: 0.5616
# Epoch 86/100
# 463/469 [============================>.] - ETA: 0s - loss: 1.9962 - categorical_accuracy: 0.6176
# Epoch 00086: loss improved from 1.99933 to 1.99582, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9958 - categorical_accuracy: 0.6167 - val_loss: 2.0650 - val_categorical_accuracy: 0.5785
# Epoch 87/100
# 448/469 [===========================>..] - ETA: 0s - loss: 1.9939 - categorical_accuracy: 0.6157
# Epoch 00087: loss improved from 1.99582 to 1.99400, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9940 - categorical_accuracy: 0.6152 - val_loss: 2.0547 - val_categorical_accuracy: 0.5686
# Epoch 88/100
# 458/469 [============================>.] - ETA: 0s - loss: 1.9939 - categorical_accuracy: 0.6154
# Epoch 00088: loss improved from 1.99400 to 1.99397, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9940 - categorical_accuracy: 0.6157 - val_loss: 2.0630 - val_categorical_accuracy: 0.6004
# Epoch 89/100
# 459/469 [============================>.] - ETA: 0s - loss: 1.9918 - categorical_accuracy: 0.6089
# Epoch 00089: loss improved from 1.99397 to 1.99223, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.9922 - categorical_accuracy: 0.6093 - val_loss: 2.0513 - val_categorical_accuracy: 0.6262
# Epoch 90/100
# 461/469 [============================>.] - ETA: 0s - loss: 1.9886 - categorical_accuracy: 0.6163
# Epoch 00090: loss improved from 1.99223 to 1.98872, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.9887 - categorical_accuracy: 0.6167 - val_loss: 2.0452 - val_categorical_accuracy: 0.6228
# Epoch 91/100
# 459/469 [============================>.] - ETA: 0s - loss: 1.9870 - categorical_accuracy: 0.6093
# Epoch 00091: loss improved from 1.98872 to 1.98616, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9862 - categorical_accuracy: 0.6099 - val_loss: 2.0510 - val_categorical_accuracy: 0.6179
# Epoch 92/100
# 439/469 [===========================>..] - ETA: 0s - loss: 1.9861 - categorical_accuracy: 0.6103
# Epoch 00092: loss did not improve from 1.98616
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9866 - categorical_accuracy: 0.6079 - val_loss: 2.0619 - val_categorical_accuracy: 0.5884
# Epoch 93/100
# 469/469 [==============================] - ETA: 0s - loss: 1.9838 - categorical_accuracy: 0.6049
# Epoch 00093: loss improved from 1.98616 to 1.98383, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9838 - categorical_accuracy: 0.6049 - val_loss: 2.0519 - val_categorical_accuracy: 0.5991
# Epoch 94/100
# 451/469 [===========================>..] - ETA: 0s - loss: 1.9812 - categorical_accuracy: 0.6040
# Epoch 00094: loss improved from 1.98383 to 1.98184, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.9818 - categorical_accuracy: 0.6049 - val_loss: 2.0328 - val_categorical_accuracy: 0.6435
# Epoch 95/100
# 452/469 [===========================>..] - ETA: 0s - loss: 1.9776 - categorical_accuracy: 0.5980
# Epoch 00095: loss improved from 1.98184 to 1.97989, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.9799 - categorical_accuracy: 0.5986 - val_loss: 2.0510 - val_categorical_accuracy: 0.5469
# Epoch 96/100
# 464/469 [============================>.] - ETA: 0s - loss: 1.9787 - categorical_accuracy: 0.5996
# Epoch 00096: loss improved from 1.97989 to 1.97769, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.9777 - categorical_accuracy: 0.5996 - val_loss: 2.0387 - val_categorical_accuracy: 0.6369
# Epoch 97/100
# 465/469 [============================>.] - ETA: 0s - loss: 1.9778 - categorical_accuracy: 0.6011
# Epoch 00097: loss did not improve from 1.97769
# 469/469 [==============================] - 1s 3ms/step - loss: 1.9782 - categorical_accuracy: 0.6008 - val_loss: 2.0778 - val_categorical_accuracy: 0.5832
# Epoch 98/100
# 454/469 [============================>.] - ETA: 0s - loss: 1.9763 - categorical_accuracy: 0.5988
# Epoch 00098: loss improved from 1.97769 to 1.97660, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 5ms/step - loss: 1.9766 - categorical_accuracy: 0.5991 - val_loss: 2.0346 - val_categorical_accuracy: 0.6255
# Epoch 99/100
# 465/469 [============================>.] - ETA: 0s - loss: 1.9721 - categorical_accuracy: 0.6011
# Epoch 00099: loss improved from 1.97660 to 1.97175, saving model to model_cond-4-64.h5
# 469/469 [==============================] - 2s 4ms/step - loss: 1.9718 - categorical_accuracy: 0.6011 - val_loss: 2.0444 - val_categorical_accuracy: 0.5704
# Epoch 100/100
# 446/469 [===========================>..] - ETA: 0s - loss: 1.9712 - categorical_accuracy: 0.5988
# Epoch 00100: loss did not improve from 1.97175
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9718 - categorical_accuracy: 0.5963 - val_loss: 2.0357 - val_categorical_accuracy: 0.5621

# %%
plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(history.history['categorical_accuracy'], label='train')
plt.plot(history.history['val_categorical_accuracy'], label='val')
plt.legend()
plt.show()

# %%
ymodel = model.predict(x_val)

# %%
ymodel1 = enc_y1.inverse_transform(ymodel[:,:3])
y_act1 = enc_y1.inverse_transform(y_val[:,:3])
ymodel2 = enc_y2.inverse_transform(ymodel[:,3:])
y_act2 = enc_y2.inverse_transform(y_val[:,3:])

# %%
from sklearn.metrics import f1_score

# %%
f1 = f1_score(ymodel1[:,0],y_act1[:,0],average='weighted')

# %%
f2 = f1_score(ymodel2[:,0],y_act2[:,0],average='weighted')

# %%
(f1+f2)*100/2
# Out:
# 85.39076561104508

# %%
86.0433
# Out:
# 86.0433
