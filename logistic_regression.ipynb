# %% [markdown]
# # Logistic Regression

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#     color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0  Brown Tabby       0.80        7.78  13   9             0.0             1
# 1        White       0.72       14.19  13   9             0.0             2
# 2        Brown       0.15       40.90  15   4             2.0             4
# 3        White       0.62       17.82   0   1             0.0             2
# 4        Black       0.50       11.06  18   4             0.0             1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18834 entries, 0 to 18833
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pet_id          18834 non-null  object
#  1   issue_date      18834 non-null  object
#  2   listing_date    18834 non-null  object
#  3   condition       17357 non-null  float64
#  4   color_type      18834 non-null  object
#  5   length(m)       18834 non-null  float64
#  6   height(cm)      18834 non-null  float64
#  7   X1              18834 non-null  int64
#  8   X2              18834 non-null  int64
#  9   breed_category  18834 non-null  float64
#  10  pet_category    18834 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# # Split Test Set

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(data, test_size=0.2, random_state=0)

# %%
train_set.head()
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 7362   ANSL_69103  2016-08-28 00:00:00  2016-12-10 13:30:00        1.0
# 9813   ANSL_50315  2016-05-27 00:00:00  2017-06-26 14:18:00        0.0
# 14596  ANSL_65268  2016-06-12 00:00:00  2017-07-03 16:22:00        NaN
# 8206   ANSL_76847  2017-03-22 00:00:00  2019-04-14 12:43:00        2.0
# 5148   ANSL_53472  2010-12-26 00:00:00  2019-01-19 17:52:00        2.0
#
#       color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 7362       Black       0.73       16.96   0   1             0.0             2
# 9813       Black       0.83       33.96   0   1             1.0             2
# 14596      Black       0.22       38.92   0   3             2.0             4
# 8206       White       0.94       20.84   0   7             0.0             2
# 5148       Black       0.06       34.82   0   7             1.0             2

# %% [markdown]
# ## Impute Missing Data

# %%
train_set["condition"].value_counts()
# Out:
# 1.0    5450
# 0.0    4998
# 2.0    3456
# Name: condition, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Used most frequent value of condition to fill in NaN entries
imputer = SimpleImputer(strategy='most_frequent')
imputer.fit(train_set[["condition"]])
train_set["condition"] = imputer.transform(train_set[["condition"]])
# Out:
# <ipython-input-82-65d44bc2d30c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set["condition"] = imputer.transform(train_set[["condition"]])

# %%
train_set.head()
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 7362   ANSL_69103  2016-08-28 00:00:00  2016-12-10 13:30:00        1.0
# 9813   ANSL_50315  2016-05-27 00:00:00  2017-06-26 14:18:00        0.0
# 14596  ANSL_65268  2016-06-12 00:00:00  2017-07-03 16:22:00        1.0
# 8206   ANSL_76847  2017-03-22 00:00:00  2019-04-14 12:43:00        2.0
# 5148   ANSL_53472  2010-12-26 00:00:00  2019-01-19 17:52:00        2.0
#
#       color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 7362       Black       0.73       16.96   0   1             0.0             2
# 9813       Black       0.83       33.96   0   1             1.0             2
# 14596      Black       0.22       38.92   0   3             2.0             4
# 8206       White       0.94       20.84   0   7             0.0             2
# 5148       Black       0.06       34.82   0   7             1.0             2

# %%
train_set["condition"].value_counts()
# Out:
# 1.0    6613
# 0.0    4998
# 2.0    3456
# Name: condition, dtype: int64

# %% [markdown]
# ## Encoding Data

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data["color_type"] = label_encoder.fit_transform(train_set["color_type"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-2ac78c9b7050> in <module>
#       2
#       3 label_encoder = LabelEncoder()
# ----> 4 data["color_type"] = label_encoder.fit_transform(train_set["color_type"])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
# ...

# %%
data.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#     color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0  Brown Tabby       0.80        7.78  13   9             0.0             1
# 1        White       0.72       14.19  13   9             0.0             2
# 2        Brown       0.15       40.90  15   4             2.0             4
# 3        White       0.62       17.82   0   1             0.0             2
# 4        Black       0.50       11.06  18   4             0.0             1

# %%
from sklearn.preprocessing import OneHotEncoder

oh_encoder = OneHotEncoder()
color_type_1h = oh_encoder.fit_transform(data[["color_type"]])

# %%
data.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        1.0
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#    color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0          18       0.80        7.78  13   9             0.0             1
# 1          53       0.72       14.19  13   9             0.0             2
# 2          15       0.15       40.90  15   4             2.0             4
# 3          53       0.62       17.82   0   1             0.0             2
# 4           2       0.50       11.06  18   4             0.0             1
