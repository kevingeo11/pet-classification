# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore')

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.initializers import glorot_uniform
from tensorflow.keras import regularizers

import keras.backend as K
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.externals.joblib import load
from keras.models import load_model
import seaborn as sb
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio

# comment the below line if you not using jupyter notebook
# %matplotlib inline

# %%
print("Started reading the data for training...")
df_ = pd.read_csv('train.csv')
df = df_.copy()
# df_training = df.iloc[:,:].copy()
print("Finished reading the data")
# Out:
# Started reading the data for training...
# Finished reading the data

# %%
df.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#     color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0  Brown Tabby       0.80        7.78  13   9             0.0             1
# 1        White       0.72       14.19  13   9             0.0             2
# 2        Brown       0.15       40.90  15   4             2.0             4
# 3        White       0.62       17.82   0   1             0.0             2
# 4        Black       0.50       11.06  18   4             0.0             1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['color_type'])
df['color_type'] = le.transform(df['color_type'])

# %%
df.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#    color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0          18       0.80        7.78  13   9             0.0             1
# 1          53       0.72       14.19  13   9             0.0             2
# 2          15       0.15       40.90  15   4             2.0             4
# 3          53       0.62       17.82   0   1             0.0             2
# 4           2       0.50       11.06  18   4             0.0             1

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(df[['breed_category']])
y = enc.transform(df[['breed_category']]).toarray()

# %%
x = df[['color_type', 'length(m)', 'height(cm)', 'X1', 'X2']].values

# %%
def scaleData(x, y):
    sc_x = StandardScaler()
    sc_y = StandardScaler()

    sc_x.fit(x)
    sc_y.fit(y)
    
    return sc_x, sc_y

# %%
sc_x, sc_y = scaleData(x,y)

# %%
x_scaled = sc_x.transform(x)

# %%
x_train = x_scaled[:15000,:]
y_train = y[:15000,:]
x_val = x_scaled[15000:,:]
y_val = y[15000:,:]

# %%
model = Sequential()
Kreg = None

model.add(Dense(512, activation = 'relu', input_shape = (x_train.shape[1],),
                kernel_initializer = glorot_uniform(seed = 1), kernel_regularizer = Kreg))

model.add(Dense(512, activation = 'relu',
                kernel_initializer = glorot_uniform(seed = 2), kernel_regularizer = Kreg))

model.add(Dense(512, activation = 'relu',
                kernel_initializer = glorot_uniform(seed = 3), kernel_regularizer = Kreg))

model.add(Dense(3, activation = 'sigmoid',
                kernel_initializer = glorot_uniform(seed = 4), kernel_regularizer = Kreg))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 512)               3072
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_23 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_24 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 529,923
# Trainable params: 529,923
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(learning_rate = 0.001)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics = ['categorical_accuracy'])

es = EarlyStopping(monitor='categorical_accuracy', mode='max', verbose=1, patience=10)
mc = ModelCheckpoint('model-4-512.h5', monitor='categorical_accuracy', mode='max', save_best_only=True, verbose=1)
callbacks = [es, mc]

history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data = (x_val,y_val),
                    verbose = 1, callbacks = callbacks)
# Out:
# Epoch 1/100
# 463/469 [============================>.] - ETA: 0s - loss: 0.8241 - categorical_accuracy: 0.5036
# Epoch 00001: categorical_accuracy improved from -inf to 0.50327, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.8237 - categorical_accuracy: 0.5033 - val_loss: 0.8216 - val_categorical_accuracy: 0.4984
# Epoch 2/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.8057 - categorical_accuracy: 0.5079
# Epoch 00002: categorical_accuracy improved from 0.50327 to 0.50793, saving model to model-4-512.h5
# 469/469 [==============================] - 7s 14ms/step - loss: 0.8059 - categorical_accuracy: 0.5079 - val_loss: 0.8153 - val_categorical_accuracy: 0.5000
# Epoch 3/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.8012 - categorical_accuracy: 0.5136
# Epoch 00003: categorical_accuracy improved from 0.50793 to 0.51320, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.8016 - categorical_accuracy: 0.5132 - val_loss: 0.8081 - val_categorical_accuracy: 0.4937
# Epoch 4/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7948 - categorical_accuracy: 0.5121
# Epoch 00004: categorical_accuracy did not improve from 0.51320
# 469/469 [==============================] - 6s 14ms/step - loss: 0.7950 - categorical_accuracy: 0.5121 - val_loss: 0.8017 - val_categorical_accuracy: 0.5177
# Epoch 5/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7899 - categorical_accuracy: 0.5132 ETA: 0s - loss: 0.7898 - categorica
# Epoch 00005: categorical_accuracy did not improve from 0.51320
# 469/469 [==============================] - 5s 12ms/step - loss: 0.7898 - categorical_accuracy: 0.5132 - val_loss: 0.8002 - val_categorical_accuracy: 0.4963
# Epoch 6/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7865 - categorical_accuracy: 0.5153
# Epoch 00006: categorical_accuracy improved from 0.51320 to 0.51500, saving model to model-4-512.h5
# 469/469 [==============================] - 7s 14ms/step - loss: 0.7865 - categorical_accuracy: 0.5150 - val_loss: 0.7949 - val_categorical_accuracy: 0.5188
# Epoch 7/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7844 - categorical_accuracy: 0.5179
# Epoch 00007: categorical_accuracy improved from 0.51500 to 0.51867, saving model to model-4-512.h5
# 469/469 [==============================] - 7s 14ms/step - loss: 0.7842 - categorical_accuracy: 0.5187 - val_loss: 0.7968 - val_categorical_accuracy: 0.5164
# Epoch 8/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7830 - categorical_accuracy: 0.5169
# Epoch 00008: categorical_accuracy did not improve from 0.51867
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7829 - categorical_accuracy: 0.5169 - val_loss: 0.7950 - val_categorical_accuracy: 0.5159
# Epoch 9/100
# 469/469 [==============================] - ETA: 0s - loss: 0.7820 - categorical_accuracy: 0.5218
# Epoch 00009: categorical_accuracy improved from 0.51867 to 0.52180, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7820 - categorical_accuracy: 0.5218 - val_loss: 0.7933 - val_categorical_accuracy: 0.5034
# Epoch 10/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7807 - categorical_accuracy: 0.5169
# Epoch 00010: categorical_accuracy did not improve from 0.52180
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7810 - categorical_accuracy: 0.5167 - val_loss: 0.7989 - val_categorical_accuracy: 0.5222
# Epoch 11/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7796 - categorical_accuracy: 0.5250
# Epoch 00011: categorical_accuracy improved from 0.52180 to 0.52480, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7797 - categorical_accuracy: 0.5248 - val_loss: 0.7938 - val_categorical_accuracy: 0.5044
# Epoch 12/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7792 - categorical_accuracy: 0.5232
# Epoch 00012: categorical_accuracy did not improve from 0.52480
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7791 - categorical_accuracy: 0.5233 - val_loss: 0.7966 - val_categorical_accuracy: 0.5198
# Epoch 13/100
# 469/469 [==============================] - ETA: 0s - loss: 0.7784 - categorical_accuracy: 0.5258
# Epoch 00013: categorical_accuracy improved from 0.52480 to 0.52580, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7784 - categorical_accuracy: 0.5258 - val_loss: 0.7900 - val_categorical_accuracy: 0.5130
# Epoch 14/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7765 - categorical_accuracy: 0.5312
# Epoch 00014: categorical_accuracy improved from 0.52580 to 0.53127, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7765 - categorical_accuracy: 0.5313 - val_loss: 0.7954 - val_categorical_accuracy: 0.5222
# Epoch 15/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7748 - categorical_accuracy: 0.5367
# Epoch 00015: categorical_accuracy improved from 0.53127 to 0.53633, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7748 - categorical_accuracy: 0.5363 - val_loss: 0.7917 - val_categorical_accuracy: 0.5216
# Epoch 16/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7729 - categorical_accuracy: 0.5401
# Epoch 00016: categorical_accuracy improved from 0.53633 to 0.53980, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7733 - categorical_accuracy: 0.5398 - val_loss: 0.7957 - val_categorical_accuracy: 0.5070
# Epoch 17/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7736 - categorical_accuracy: 0.5386
# Epoch 00017: categorical_accuracy did not improve from 0.53980
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7738 - categorical_accuracy: 0.5387 - val_loss: 0.7897 - val_categorical_accuracy: 0.5219
# Epoch 18/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7713 - categorical_accuracy: 0.5420
# Epoch 00018: categorical_accuracy improved from 0.53980 to 0.54180, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7712 - categorical_accuracy: 0.5418 - val_loss: 0.7912 - val_categorical_accuracy: 0.5230
# Epoch 19/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7711 - categorical_accuracy: 0.5417
# Epoch 00019: categorical_accuracy did not improve from 0.54180
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7707 - categorical_accuracy: 0.5409 - val_loss: 0.7915 - val_categorical_accuracy: 0.5310
# Epoch 20/100
# 469/469 [==============================] - ETA: 0s - loss: 0.7693 - categorical_accuracy: 0.5447
# Epoch 00020: categorical_accuracy improved from 0.54180 to 0.54473, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7693 - categorical_accuracy: 0.5447 - val_loss: 0.7963 - val_categorical_accuracy: 0.5248
# Epoch 21/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7675 - categorical_accuracy: 0.5468
# Epoch 00021: categorical_accuracy improved from 0.54473 to 0.54653, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7681 - categorical_accuracy: 0.5465 - val_loss: 0.7921 - val_categorical_accuracy: 0.5261
# Epoch 22/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7667 - categorical_accuracy: 0.5481 ETA: 0s - loss: 0.7660 - cate
# Epoch 00022: categorical_accuracy improved from 0.54653 to 0.54800, saving model to model-4-512.h5
# 469/469 [==============================] - 7s 15ms/step - loss: 0.7667 - categorical_accuracy: 0.5480 - val_loss: 0.7894 - val_categorical_accuracy: 0.5305
# Epoch 23/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7661 - categorical_accuracy: 0.5499 ETA: 0s - loss: 0.7666 - categorica
# Epoch 00023: categorical_accuracy improved from 0.54800 to 0.55007, saving model to model-4-512.h5
# 469/469 [==============================] - 7s 15ms/step - loss: 0.7657 - categorical_accuracy: 0.5501 - val_loss: 0.7953 - val_categorical_accuracy: 0.5222
# Epoch 24/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7647 - categorical_accuracy: 0.5492
# Epoch 00024: categorical_accuracy did not improve from 0.55007
# 469/469 [==============================] - 7s 15ms/step - loss: 0.7649 - categorical_accuracy: 0.5491 - val_loss: 0.7884 - val_categorical_accuracy: 0.5295
# Epoch 25/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7632 - categorical_accuracy: 0.5475 ETA: 0s - loss: 0.7638 - ca
# Epoch 00025: categorical_accuracy did not improve from 0.55007
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7633 - categorical_accuracy: 0.5475 - val_loss: 0.7968 - val_categorical_accuracy: 0.5214
# Epoch 26/100
# 469/469 [==============================] - ETA: 0s - loss: 0.7626 - categorical_accuracy: 0.5527
# Epoch 00026: categorical_accuracy improved from 0.55007 to 0.55267, saving model to model-4-512.h5
# 469/469 [==============================] - 10s 21ms/step - loss: 0.7626 - categorical_accuracy: 0.5527 - val_loss: 0.7973 - val_categorical_accuracy: 0.5237
# Epoch 27/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7614 - categorical_accuracy: 0.5529
# Epoch 00027: categorical_accuracy improved from 0.55267 to 0.55280, saving model to model-4-512.h5
# 469/469 [==============================] - 8s 18ms/step - loss: 0.7615 - categorical_accuracy: 0.5528 - val_loss: 0.7978 - val_categorical_accuracy: 0.5331
# Epoch 28/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7597 - categorical_accuracy: 0.5519
# Epoch 00028: categorical_accuracy did not improve from 0.55280
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7595 - categorical_accuracy: 0.5520 - val_loss: 0.7934 - val_categorical_accuracy: 0.5290
# Epoch 29/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7591 - categorical_accuracy: 0.5570
# Epoch 00029: categorical_accuracy improved from 0.55280 to 0.55747, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.7586 - categorical_accuracy: 0.5575 - val_loss: 0.7978 - val_categorical_accuracy: 0.5227
# Epoch 30/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7571 - categorical_accuracy: 0.5565
# Epoch 00030: categorical_accuracy did not improve from 0.55747
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7567 - categorical_accuracy: 0.5567 - val_loss: 0.7963 - val_categorical_accuracy: 0.5209
# Epoch 31/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7552 - categorical_accuracy: 0.5562
# Epoch 00031: categorical_accuracy did not improve from 0.55747
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7551 - categorical_accuracy: 0.5566 - val_loss: 0.7926 - val_categorical_accuracy: 0.5216
# Epoch 32/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.7554 - categorical_accuracy: 0.5579
# Epoch 00032: categorical_accuracy did not improve from 0.55747
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7558 - categorical_accuracy: 0.5573 - val_loss: 0.7911 - val_categorical_accuracy: 0.5232
# Epoch 33/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7533 - categorical_accuracy: 0.5580
# Epoch 00033: categorical_accuracy improved from 0.55747 to 0.55853, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.7533 - categorical_accuracy: 0.5585 - val_loss: 0.7984 - val_categorical_accuracy: 0.5276
# Epoch 34/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7503 - categorical_accuracy: 0.5601
# Epoch 00034: categorical_accuracy improved from 0.55853 to 0.56020, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7506 - categorical_accuracy: 0.5602 - val_loss: 0.7965 - val_categorical_accuracy: 0.5305
# Epoch 35/100
# 463/469 [============================>.] - ETA: 0s - loss: 0.7497 - categorical_accuracy: 0.5612
# Epoch 00035: categorical_accuracy improved from 0.56020 to 0.56113, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7499 - categorical_accuracy: 0.5611 - val_loss: 0.7989 - val_categorical_accuracy: 0.5339
# Epoch 36/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.7499 - categorical_accuracy: 0.5615
# Epoch 00036: categorical_accuracy improved from 0.56113 to 0.56180, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7500 - categorical_accuracy: 0.5618 - val_loss: 0.8040 - val_categorical_accuracy: 0.5276
# Epoch 37/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7491 - categorical_accuracy: 0.5644
# Epoch 00037: categorical_accuracy improved from 0.56180 to 0.56413, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7493 - categorical_accuracy: 0.5641 - val_loss: 0.8006 - val_categorical_accuracy: 0.5201
# Epoch 38/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7471 - categorical_accuracy: 0.5619
# Epoch 00038: categorical_accuracy did not improve from 0.56413
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7469 - categorical_accuracy: 0.5617 - val_loss: 0.7962 - val_categorical_accuracy: 0.5305
# Epoch 39/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7450 - categorical_accuracy: 0.5604 ETA: 0s - loss: 0.7431 - categorical_accu
# Epoch 00039: categorical_accuracy did not improve from 0.56413
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7451 - categorical_accuracy: 0.5604 - val_loss: 0.8016 - val_categorical_accuracy: 0.5274
# Epoch 40/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7445 - categorical_accuracy: 0.5639
# Epoch 00040: categorical_accuracy did not improve from 0.56413
# 469/469 [==============================] - 7s 14ms/step - loss: 0.7448 - categorical_accuracy: 0.5639 - val_loss: 0.7958 - val_categorical_accuracy: 0.5305
# Epoch 41/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7410 - categorical_accuracy: 0.5648
# Epoch 00041: categorical_accuracy improved from 0.56413 to 0.56440, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7415 - categorical_accuracy: 0.5644 - val_loss: 0.7928 - val_categorical_accuracy: 0.5373
# Epoch 42/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7405 - categorical_accuracy: 0.5644
# Epoch 00042: categorical_accuracy improved from 0.56440 to 0.56460, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7404 - categorical_accuracy: 0.5646 - val_loss: 0.7956 - val_categorical_accuracy: 0.5334
# Epoch 43/100
# 469/469 [==============================] - ETA: 0s - loss: 0.7392 - categorical_accuracy: 0.5649
# Epoch 00043: categorical_accuracy improved from 0.56460 to 0.56493, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.7392 - categorical_accuracy: 0.5649 - val_loss: 0.7958 - val_categorical_accuracy: 0.5313
# Epoch 44/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7386 - categorical_accuracy: 0.5669
# Epoch 00044: categorical_accuracy improved from 0.56493 to 0.56713, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.7383 - categorical_accuracy: 0.5671 - val_loss: 0.8039 - val_categorical_accuracy: 0.5310
# Epoch 45/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7369 - categorical_accuracy: 0.5670
# Epoch 00045: categorical_accuracy did not improve from 0.56713
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7372 - categorical_accuracy: 0.5667 - val_loss: 0.8072 - val_categorical_accuracy: 0.5209
# Epoch 46/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7347 - categorical_accuracy: 0.5657 ETA: 2s - loss: - ETA: 1s - loss: 0.7325 - categorical_accura - ETA: 1s - loss: 0
# Epoch 00046: categorical_accuracy did not improve from 0.56713
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7346 - categorical_accuracy: 0.5656 - val_loss: 0.8056 - val_categorical_accuracy: 0.5363
# Epoch 47/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7413 - categorical_accuracy: 0.5554
# Epoch 00047: categorical_accuracy did not improve from 0.56713
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7417 - categorical_accuracy: 0.5555 - val_loss: 0.8226 - val_categorical_accuracy: 0.5128
# Epoch 48/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7379 - categorical_accuracy: 0.5616
# Epoch 00048: categorical_accuracy did not improve from 0.56713
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7381 - categorical_accuracy: 0.5617 - val_loss: 0.8208 - val_categorical_accuracy: 0.5167
# Epoch 49/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7383 - categorical_accuracy: 0.5626
# Epoch 00049: categorical_accuracy did not improve from 0.56713
# 469/469 [==============================] - 8s 16ms/step - loss: 0.7382 - categorical_accuracy: 0.5623 - val_loss: 0.8222 - val_categorical_accuracy: 0.5183
# Epoch 50/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7379 - categorical_accuracy: 0.5595
# Epoch 00050: categorical_accuracy did not improve from 0.56713
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7379 - categorical_accuracy: 0.5595 - val_loss: 0.8190 - val_categorical_accuracy: 0.5237
# Epoch 51/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.7376 - categorical_accuracy: 0.5707
# Epoch 00051: categorical_accuracy improved from 0.56713 to 0.56993, saving model to model-4-512.h5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.7380 - categorical_accuracy: 0.5699 - val_loss: 0.8051 - val_categorical_accuracy: 0.5370
# Epoch 52/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.7322 - categorical_accuracy: 0.5724
# Epoch 00052: categorical_accuracy improved from 0.56993 to 0.57253, saving model to model-4-512.h5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.7323 - categorical_accuracy: 0.5725 - val_loss: 0.8158 - val_categorical_accuracy: 0.5347
# Epoch 53/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7351 - categorical_accuracy: 0.5666
# Epoch 00053: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 10ms/step - loss: 0.7349 - categorical_accuracy: 0.5667 - val_loss: 0.8199 - val_categorical_accuracy: 0.5159
# Epoch 54/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.7321 - categorical_accuracy: 0.5652
# Epoch 00054: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7325 - categorical_accuracy: 0.5642 - val_loss: 0.8237 - val_categorical_accuracy: 0.5224
# Epoch 55/100
# 465/469 [============================>.] - ETA: 0s - loss: 0.7304 - categorical_accuracy: 0.5640
# Epoch 00055: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 10ms/step - loss: 0.7311 - categorical_accuracy: 0.5639 - val_loss: 0.8273 - val_categorical_accuracy: 0.5245
# Epoch 56/100
# 467/469 [============================>.] - ETA: 0s - loss: 0.7302 - categorical_accuracy: 0.5682
# Epoch 00056: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7302 - categorical_accuracy: 0.5683 - val_loss: 0.8389 - val_categorical_accuracy: 0.5230
# Epoch 57/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7282 - categorical_accuracy: 0.5650
# Epoch 00057: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7283 - categorical_accuracy: 0.5649 - val_loss: 0.8260 - val_categorical_accuracy: 0.5321
# Epoch 58/100
# 463/469 [============================>.] - ETA: 0s - loss: 0.7296 - categorical_accuracy: 0.5669
# Epoch 00058: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 10ms/step - loss: 0.7297 - categorical_accuracy: 0.5670 - val_loss: 0.8241 - val_categorical_accuracy: 0.5159
# Epoch 59/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.7307 - categorical_accuracy: 0.5621
# Epoch 00059: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 6s 13ms/step - loss: 0.7309 - categorical_accuracy: 0.5621 - val_loss: 0.8281 - val_categorical_accuracy: 0.5198
# Epoch 60/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.7240 - categorical_accuracy: 0.5693
# Epoch 00060: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7243 - categorical_accuracy: 0.5689 - val_loss: 0.8487 - val_categorical_accuracy: 0.5240
# Epoch 61/100
# 468/469 [============================>.] - ETA: 0s - loss: 0.7236 - categorical_accuracy: 0.5702
# Epoch 00061: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7238 - categorical_accuracy: 0.5699 - val_loss: 0.8421 - val_categorical_accuracy: 0.5240
# Epoch 62/100
# 464/469 [============================>.] - ETA: 0s - loss: 0.7259 - categorical_accuracy: 0.5712
# Epoch 00062: categorical_accuracy did not improve from 0.57253
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7263 - categorical_accuracy: 0.5705 - val_loss: 0.8219 - val_categorical_accuracy: 0.5279
# Epoch 00062: early stopping

# %%
plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(history.history['categorical_accuracy'], label='train')
plt.plot(history.history['val_categorical_accuracy'], label='val')
plt.legend()
plt.show()

# %%
ymodel = model.predict(x_val)

# %%
ymodel = enc.inverse_transform(ymodel)
y_act = enc.inverse_transform(y_val)

# %%
from sklearn.metrics import f1_score

# %%
f1_score(ymodel[:,0],y_act[:,0],average='weighted')
# Out:
# 0.5573813349510126
